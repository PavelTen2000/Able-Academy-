# %% [markdown]
# # Пожалуйста, выполните задачи ниже.
#
# Вам может понадобиться больше узнать о методах, предоставляемых пакетом Numpy.
#
# **Пожалуйста, не удаляйте комментарии !!!**

# %% [markdown]
# 1. Импортируйте необходимые пакеты самостоятельно.

# %%
# Начало вашего кода
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
import seaborn as sns
# Конец вашего кода
print(np)
print(pd)
print(sns)
print(plt)
# Out:
# <module 'numpy' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\numpy\\__init__.py'>
# <module 'pandas' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\pandas\\__init__.py'>
# <module 'seaborn' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\seaborn\\__init__.py'>
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# ### Ожидаемый результат:
#
# ```
# <module 'numpy' from '/Users/st/anaconda3/envs/py36-ds/lib/python3.6/site-packages/numpy/__init__.py'>
# <module 'pandas' from '/Users/st/anaconda3/envs/py36-ds/lib/python3.6/site-packages/pandas/__init__.py'>
# <module 'seaborn' from '/Users/st/anaconda3/envs/py36-ds/lib/python3.6/site-packages/seaborn/__init__.py'>
# <module 'matplotlib.pyplot' from '/Users/st/anaconda3/envs/py36-ds/lib/python3.6/site-packages/matplotlib/pyplot.py'>
# ```

# %% [markdown]
# 2. Загрузите данные ```"exercise"``` в ```pandas.DataFrame``` из ```seaborn```.

# %%
exercise,
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
df = exercise
l = df.columns.values
plt.figure(figsize=(17,5))
for i in range(0,len(l)):
    plt.subplot(1,6,i+1)
    sns.set_style('whitegrid')
    sns.distplot(exercise['pulse'], kde = True)
    plt.tight_layout()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Начало вашего кода
exercise = sns.load_dataset('exercise')
# Конец вашего кода
exercise.head()
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %% [markdown]
# ### Ожидаемый результат:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. Пожалуйста, обработайте данные так, чтобы у вас был следующий DataFrame. Преобразуйте категориальные данные в целые числа.
#
# ![image.png](attachment:image.png)

# %%
pd_data=exercise.copy()
# Начало вашего кода
pd_data = pd_data.set_index('Unnamed: 0')
pd_data.index.name = ''
pd_data['diet-int'] = pd_data['diet'].replace(['low fat' , 'no fat'], [0,1])
pd_data['time-int'] = pd_data['time'].replace(['1 min' ,'15 min' ,'30 min'], [0,1,2])
pd_data['kind-int'] = pd_data['kind'].replace(['rest', 'walking', 'running'], [0,1,2])

# Конец вашего кода
pd_data.head()
# Out:
#    id     diet  pulse    time  kind  diet-int  time-int  kind-int
#
# 0   1  low fat     85   1 min  rest         0         0         0
# 1   1  low fat     85  15 min  rest         0         1         0
# 2   1  low fat     88  30 min  rest         0         2         0
# 3   2  low fat     90   1 min  rest         0         0         0
# 4   2  low fat     92  15 min  rest         0         1         0

# %% [markdown]
# 4. Построить график с матрицей корреляции.
#
# **Примечание:** используйте ```coolwarm``` для ```cmap```.
#
# ![image.png](attachment:image.png)

# %%
# Начало вашего кода
sns.heatmap(pd_data[['id' , 'pulse'  , 'diet-int' ,'time-int' , 'kind-int']].corr() , cmap = 'coolwarm');
plt.xticks([0.5,1.5,2.5,3.5,4.5],labels = ['id' , 'pulse'  , 'diet-int' ,'time-int' , 'kind-int'], rotation = 90);
plt.yticks([0.5,1.5,2.5,3.5,4.5],labels = ['id' , 'pulse'  , 'diet-int' ,'time-int' , 'kind-int'], rotation = 0);

# Конец вашего кода

# %%
'''
Ваши наблюдения:
"kind-int" и 'id' очень сильно коррелируют между собой. Также сильно кореелируют, 'id' и 'pulse', 'pulse' и 'kind-int'.
Последнее можно объянить тем, что в зависимости от того какой деятельностью ты занимаешься у тебя будет разный пульс.
(walking, rest , running)
''';

# %% [markdown]
# 5. Пожалуйста, произведите следующий график, показанный ниже:
#
# ![image.png](attachment:image.png)

# %%
# Начало вашего кода
sns.set(style = 'whitegrid')
sns.set_context('talk')
g = sns.pairplot(pd_data[['id','pulse','kind-int','time-int']], corner = True, diag_kind = 'kde')

# Конец вашего кода

# %%
'''
Ваши наблюдения:
Кол-во всех уникальных значений "id" равно, больше всего значений 'pulse' в районе 90-100, распределение 'time-int' и 'kind-int'
примерно одинаковое. Чем выше id тем выше пульс. Первая треть участников занималась отдыхом, вторая ходила и третья бегала. 
Те кто отдыхали у них самый низкий пульс, те кто ходили чуть больше и те кто бегали среди них есть те у кого значительно
выше пульс. Все участники делали свою активность в 3 временных периодах(1 м, 15м, 30м). Тем больше время тем более вероятность
высокого пульса. Каждая активность была совершена в 3 временых перидодах. 
'''
# Out:
# '\nВаши наблюдения:\n\n'

# %% [markdown]
# 6. Пожалуйста, произведите следующий график:
#
# ![image.png](attachment:image.png)

# %%
# Начало вашего кода
sns.relplot(x = 'id', y = 'pulse', data= pd_data, hue = 'kind', size = 'time', size_order = ['30 min', '15 min', '1 min']);
# Конец вашего кода

# %%
'''
Ваши наблюдения:
Тем выше Айди тем выше пульс, это потому что люди с выше айди(20+) занимались бегом, а люди с 10-20 занимались ходьбой. Все 
делали свое занятие в 3-х промежутках времени. Самый большой пульс у тех кто бегал 30 минут. 
''';

# %% [markdown]
# 7. Пожалуйста, произведите следующий график:
#
# ![image.png](attachment:image.png)
#
# **Примечание:**
#
# 1. Размер ```figure``` установлен на (10,10)
# 2. Пожалуйста, проверьте метод ```tight_layout()```

# %%
# Начало вашего кода
sns.set_context('talk')
fig = plt.figure(figsize = (10,10));
axs1 = fig.add_subplot(1,2,1)
axs2 = fig.add_subplot(3,2,2)
axs3 = fig.add_subplot(3,2,4)
axs4 = fig.add_subplot(3,2,6)
sns.scatterplot(x = 'id', y = 'pulse', data= pd_data, ax = axs1, size = 'time', size_order = ['30 min', '15 min', '1 min'],
               hue = 'kind');
sns.swarmplot(x = 'time', y = 'pulse', data = pd_data, ax = axs2);
sns.boxplot(x = 'kind', y = 'pulse', data = pd_data, ax = axs3);
sns.violinplot(x = 'diet', y = 'pulse', data = pd_data, ax = axs4);

plt.tight_layout()
# Конец вашего кода

# %%
'''
Ваши наблюдения:
У большинства тех кто занимался 1 мин пульс менее 100, у тех кто занимался 15 мин у примерно 70% пульс меньше 100, и те кто 
занимался 30 мин примерно половина >100. Пульс у тех кто бегал очень сильно отличается от 2-х других. Медиана пульса 
больше на 10-20, в основном находится в районе 100-120. Медиана хождение чуть больше чем медиана пульса отдыха. Разница не 
такая значимая как с бегом .

''';

# %% [markdown]
# 8. Загрузите данные ```"flights"``` в ```pandas.DataFrame``` из ```seaborn```.
#
# ![image.png](attachment:image.png)

# %%
# Начало вашего кода
flights = sns.load_dataset('flights')
# Конец вашего кода
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %% [markdown]
# 9. Пожалуйста, произведите следующий график, показанный ниже:
#
# ![image.png](attachment:image.png)

# %%
# Начало вашего кода
sns.set(style = 'darkgrid')
sns.set_context('talk')

g = sns.FacetGrid(flights , col = 'month', col_wrap = 4);
g.map(sns.scatterplot, 'year', 'passengers');
# Конец вашего кода

# %% [markdown]
# 10. Пожалуйста, произведите следующий график, показанный ниже:
#
# ![image.png](attachment:image.png)
#
# **Примечание:** используйте ```bright``` для ```cmap```.

# %%
###### Начало вашего кода
sns.set(style = 'ticks')
sns.set_context('talk')
sns.relplot('year', 'passengers', data = flights, hue = 'month', cmap = 'bright');
plt.xticks([1950, 1955, 1960]);
sns.despine(trim = True)
# Конец вашего кода
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
'''
Ваши наблюдения:
Во всех месяцах наблюдается рост пассажиров. Везде также наблюдается небольшая просадка клиентов в период 1953-1954 года. 
Самое активное время года это лето. Рост клиентов начинается в апреле и достигает пика в июле и августе. Затем потихонько 
снижается с каждым месяцем. Самые не активные месяца февраль и ноябрь. 
''';

# %% [markdown]
# # Прекрасная работа!
