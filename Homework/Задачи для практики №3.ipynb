# %% [markdown]
# # Пожалуйста, выполните задачи ниже.
#
# Вам может понадобиться больше узнать о методах, предоставляемых пакетом Numpy.
#
# **Пожалуйста, не удаляйте комментарии !!!**

# %% [markdown]
# 1. Импортируйте необходимые пакеты самостоятельно.

# %%
# Начало вашего кода
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# Конец вашего кода
print(np)
print(pd)
print(plt)
# Out:
# <module 'numpy' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\numpy\\__init__.py'>
# <module 'pandas' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\pandas\\__init__.py'>
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# ### Ожидаемый результат:
#
# ```
# <module 'numpy' from '/Users/st/anaconda3/envs/py36-ds/lib/python3.6/site-packages/numpy/__init__.py'>
# <module 'pandas' from '/Users/st/anaconda3/envs/py36-ds/lib/python3.6/site-packages/pandas/__init__.py'>
# <module 'matplotlib.pyplot' from '/Users/st/anaconda3/envs/py36-ds/lib/python3.6/site-packages/matplotlib/pyplot.py'>
# ```

# %% [markdown]
# 2. Прочитайте данные из "salaries.csv" в pandas.DataFrame.

# %%
# Начало вашего кода
data = pd.read_csv('salaries.csv')
# Конец вашего кода
pd_data=data.copy()
data.head()
# Out:
#    salary experience  gender married  age
# 0   43003         >5    male     yes   29
# 1   22172        3-5  female     yes   28
# 2   15192        3-5  female     yes   28
# 3   42511         >5    male      no   24
# 4   17813        3-5    male     yes   27

# %% [markdown]
# ### Ожидаемый результат:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. Пожалуйста, произведите следующий график, показанный ниже (ширина = 0,5):
#
# ![image.png](attachment:image.png)

# %%
# Начало вашего кода
plt.bar(x = ['male', 'female'], height = [data['gender'].value_counts()['male'], data['gender'].value_counts()['female']], 
       width = 0.5);
plt.ylabel('Counts');
plt.title('Counts gender');
# Конец вашего кода

# %% [markdown]
# 4. Пожалуйста, произведите следующий график, показанный ниже (ширина = 0,5):
#
# ![image.png](attachment:image.png)

# %%
data['married'].value_counts()['yes']
# Out:
# 254

# %%
# Начало вашего кода
plt.bar(x = [data['married'].unique()[0], data['married'].unique()[1]] ,
        height = [data['married'].value_counts()[0], data['married'].value_counts()[1]],
       width = 0.5);
plt.ylabel('Counts');
plt.title('Counts marriage status');
# Конец вашего кода

# %% [markdown]
# 5. Пожалуйста, произведите следующий график, показанный ниже (ширина = 0,5):
#
# ![image.png](attachment:image.png)

# %%
# Начало вашего кода
a , b ,c = pd_data['experience'].unique()
count_a , count_b, count_c = pd_data['experience'].value_counts()
plt.bar(x = [a,b,c] , height = [count_a , count_b, count_c], width = 0.5);
plt.title('Counts experience years');
plt.ylabel('Counts');
# Конец вашего кода

# %% [markdown]
# 6. Пожалуйста, произведите следующий график, показанный ниже (ширина = 0,5):
#
# ![image.png](attachment:image.png)

# %%
## Начало вашего кода
for i in pd_data['experience'].unique():
    plt.scatter(x = pd_data[pd_data['experience'] == i]['age'], 
                y = pd_data[pd_data['experience'] == i]['salary'], label = i)
plt.xlabel('Age')
plt.ylabel('Salary')
plt.legend()
plt.show()
# Конец вашего кода

# %% [markdown]
# 7. Теперь, пожалуйста, объедините три графика выше в одну красивую фигуру, как показано ниже:
#
#
# ![image.png](attachment:image.png)
#
# **Примечание:**
#
# 1. Размер ```figure``` установлен на (10,7)
# 2. $\alpha$ установлена 0.3 для всех subplots.
# 3. для subplot Age vs Salary ```xlim - [21,5,29,5]```, а ```ylim - [9000,51000]```
# 4. Пожалуйста, проверьте метод ```tight_layout()```

# %%
### Начало вашего кода
fig = plt.figure(figsize = (10,7))
axs1 = fig.add_subplot(1,2,1)
axs2 =fig.add_subplot(3,2,2)
axs3 =fig.add_subplot(3,2,4)
axs4 =fig.add_subplot(3,2,6)

axs1.scatter(x = pd_data[pd_data['experience'] == '0-2']['age'], y = pd_data[pd_data['experience'] == '0-2']['salary'], label = '0-2', color = 'r')
axs1.scatter(x = pd_data[pd_data['experience'] == '3-5']['age'], y = pd_data[pd_data['experience'] == '3-5']['salary'], label = '3-5', color = 'b')
axs1.scatter(x = pd_data[pd_data['experience'] == '>5']['age'], y = pd_data[pd_data['experience'] == '>5']['salary'], label = '>5', color = 'g')
axs1.set_xlabel('Age')
axs1.set_ylabel('Salary')
axs1.fill_between(x = np.arange(21,31,1) , y1 = 9000, y2 =15000, alpha = 0.3, color = 'r')
axs1.fill_between(x = np.arange(21,31,1) , y1 = 15000, y2 =30000, alpha = 0.3, color = 'b')
axs1.fill_between(x = np.arange(21,31,1) , y1 = 30000, y2 =51000, alpha = 0.3, color = 'g')

axs1.set_ylim(9000,51000)
axs1.set_xlim(21.5,29.5) 

male = pd_data['gender'].value_counts()[1]
female = pd_data['gender'].value_counts()[0]
axs2.bar(x = ['male', 'female'] , height = [male, female], color = ['b', 'r'], alpha = 0.3, width = 0.3)
axs2.set_title('Counts gender', fontsize = 15)

yes = pd_data['married'].value_counts()[0]
no = pd_data['married'].value_counts()[1]
axs3.bar(x = ['yes', 'no'] , height = [yes, no], color = ['b', 'r'], alpha = 0.3, width = 0.3)
axs3.set_title('Counts marriage status', fontsize = 15)

exp_5 = pd_data['experience'].value_counts()[0]
exp_3 = pd_data['experience'].value_counts()[1]
exp_0 = pd_data['experience'].value_counts()[2]
axs4.bar(x = ['>5', '3-5', '0-2'] , height = [exp_5, exp_3,exp_0], color = ['b', 'r', 'g'], alpha = 0.3, width = 0.3)
axs4.set_title('Counts experience years', fontsize = 15)
[i.set_ylabel('Counts') for i in [axs2,axs3,axs4]]

plt.tight_layout()
axs1.legend()
plt.show()

# Конец вашего кода

# %% [markdown]
# 8. Пожалуйста, произведите следующий график, показанный ниже (размер figure установлен на (10,7)):
#
# ![image.png](attachment:image.png)

# %%
# Начало вашего кода
fig = plt.figure(figsize = (10,7))
Male = pd_data[pd_data['gender'] == 'male']
Female = pd_data[pd_data['gender'] == 'female']
Married = pd_data[pd_data['married'] == 'yes']
Single = pd_data[pd_data['married'] == 'no']
names = ['', 'Male', 'Female', 'Married', 'Single']
for num , cat in enumerate([Male, Female, Married, Single], 1):
    axs = fig.add_subplot(2,2,num)
    axs.boxplot(x = [cat[cat['experience'] == '0-2']['salary'],
                     cat[cat['experience'] == '3-5']['salary'], 
                     cat[cat['experience'] == '>5']['salary']] )
    if num == 1 or num == 3:
        axs.set_ylabel('Salary')
    axs.set_title(names[num])
    axs.set_xlabel('Experience level')
    axs.set_xticklabels(['0-2', '2-5','>5'], rotation = 45)
plt.tight_layout()

# Конец вашего кода

# %% [markdown]
# 9. Пожалуйста, произведите следующий график, показанный ниже (размер figure установлен на (10,7)):
#
# ![image.png](attachment:image.png)

# %%
# Начало вашего кода
fig = plt.figure(figsize = (10,7))
Male = pd_data[pd_data['gender'] == 'male']
Female = pd_data[pd_data['gender'] == 'female']
Married = pd_data[pd_data['married'] == 'yes']
Single = pd_data[pd_data['married'] == 'no']
names = ['', 'Male', 'Female', 'Married', 'Single']
for num , cat in enumerate([Male, Female , Married, Single],1):
    axs = fig.add_subplot(2,2,num)
    axs.bar(x = ['0-2', '3-5', '>5'], 
            height = [(cat['experience']=='0-2').sum(),(cat['experience']=='3-5').sum(), (cat['experience']=='>5').sum()],
           color = ['r', 'b', 'g'], edgecolor = 'k')
    axs.set_title(names[num])
    axs.set_xlabel('Experience level')
    axs.set_xticklabels(['0-2', '2-5', '>5'], rotation = 45)
    axs.set_ylabel('Salary')
plt.tight_layout()
# Конец вашего кода
# Out:
# <ipython-input-121-2b3c0d4160e7>:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs.set_xticklabels(['0-2', '2-5', '>5'], rotation = 45)

# %% [markdown]
# 10. Пожалуйста, произведите следующий график, показанный ниже:
#
# ![image.png](attachment:image.png)
#
# **Примечание:**
#
# 1. Размер figure установлен на ```(10,5)```
# 2. Пожалуйста, проверьте метод ```tight_layout()```
# 3. ```width=0.4```

# %%
# Начало вашего кода
plt.rcParams['figure.figsize'] = 10,5
fig , axs = plt.subplots(1,2)
Male = pd_data[pd_data['gender'] == 'male']
Female = pd_data[pd_data['gender'] == 'female']
Married = pd_data[pd_data['married'] == 'yes']
Single = pd_data[pd_data['married'] == 'no']
names = ['Male & Female', 'Married & Single']
for num , cat in enumerate([[Male, Female], [Married, Single]]):
    axs[num].bar(x = ['0-2', '2-5', '>5'], 
                 height = [(cat[0]['experience'] == '0-2').sum(),(cat[0]['experience'] == '3-5').sum(), 
                           (cat[0]['experience'] == '>5').sum()], color = 'b', label = ['male', 'yes'][num], 
                 width = -0.4, align = 'edge', edgecolor = 'k')
    axs[num].bar(x = ['0-2', '2-5', '>5'], 
                 height = [(cat[1]['experience'] == '0-2').sum(),(cat[1]['experience'] == '3-5').sum(), 
                           (cat[1]['experience'] == '>5').sum()], color = 'r', label = ['female', 'no'][num],
                 width = 0.4, align = 'edge', edgecolor = 'k')
    
    axs[num].legend()
    axs[num].set_title(names[num])
    axs[num].set_xlabel('Experience level')
    axs[num].set_ylabel('Salary')
    axs[num].set_xticklabels(['0-2','3-5', '>5'], rotation = 45)
    plt.tight_layout()
# Конец вашего кода
# Out:
# <ipython-input-183-16dde15cad18>:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[num].set_xticklabels(['0-2','3-5', '>5'], rotation = 45)

# %% [markdown]
# # Прекрасная работа!
