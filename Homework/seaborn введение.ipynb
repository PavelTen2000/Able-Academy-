# %% [markdown]
# ### seaborn: Введение [Домашнее задание]
# > **Вы должны импортировать все необходимые пакеты самостоятельно.**
#
# > **Пишите код только там, где это показано для записи. Не удаляйте комментарии!**
#
# > **Пожалуйста, установите все необходимые пакеты самостоятельно.**

# %% [markdown]
# ### Шаг 1
#
# Импортируйте все необходимые пакеты, чтобы получить ожидаемые результаты.

# %%
#Начало вашего кода
import os 
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np
import seaborn as sns
#Конец вашего кода
print(os)
print(np)
print(pd)
print(plt)
print(sns)
# Out:
# <module 'os' from 'C:\\ProgramData\\Anaconda3\\lib\\os.py'>
# <module 'numpy' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\numpy\\__init__.py'>
# <module 'pandas' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\pandas\\__init__.py'>
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>
# <module 'seaborn' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\seaborn\\__init__.py'>

# %% [markdown]
# ### Ожидаемый результат:
#
# ```
# <module 'os' from '/Users/st/anaconda3/envs/py36-ds/lib/python3.6/os.py'>
# <module 'numpy' from '/Users/st/anaconda3/envs/py36-ds/lib/python3.6/site-packages/numpy/__init__.py'>
# <module 'pandas' from '/Users/st/anaconda3/envs/py36-ds/lib/python3.6/site-packages/pandas/__init__.py'>
# <module 'matplotlib.pyplot' from '/Users/st/anaconda3/envs/py36-ds/lib/python3.6/site-packages/matplotlib/pyplot.py'>
# <module 'seaborn' from '/Users/st/anaconda3/envs/py36-ds/lib/python3.6/site-packages/seaborn/__init__.py'>
# ```

# %% [markdown]
# Пожалуйста, перечислите все встроенные наборы данных ```datasets``` в пакете seaborn:

# %%
#Начало вашего кода
datasets = sns.get_dataset_names()
#Конец вашего кода
for dataname in datasets:
    print(dataname)
# Out:
# anagrams
# anscombe
# attention
# brain_networks
# car_crashes
# diamonds
# dots
# exercise
# flights
# fmri
# gammas
# geyser
# iris
# mpg
# penguins
# planets
# taxis
# tips
# titanic

# %% [markdown]
# ### Ожидаемый результат:
#
# ```
# anscombe
# attention
# brain_networks
# car_crashes
# diamonds
# dots
# exercise
# flights
# fmri
# gammas
# iris
# mpg
# planets
# tips
# titanic
# ```

# %% [markdown]
# ### Шаг 2
#
# Загрузите набор данных ```"titanic"``` в переменную ```titanic```:

# %%
#Начало вашего кода
titanic = sns.load_dataset('titanic')
#Конец вашего кода
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ### Ожидаемый результат:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Шаг 3
#
# Сделайте фигуру, как показано ниже (высота фигуры = 7 и ширина фигуры = 7)
#
# ### Ожидаемый результат:
#
# ![image.png](attachment:image.png)

# %%
#Начало вашего кода
sns.relplot(x = 'age' , y = 'fare', data = titanic, hue = 'sex', height = 7, aspect = 1);
plt.title('Age vs Fare', fontsize = 15);
#Конец вашего кода

# %% [markdown]
# ### Шаг 4
#
# Пожалуйста, реализуйте функцию ```plot_sns_pclass(data=None)```, которая отображает несколько фигур, каждая фигура содержит визуализацию на основе класса пассажира.
#
# **Замечания: высота фигуры = 4 и ширина фигуры = 8**

# %%
def plot_sns_pclass(data=None):
    #Начало вашего кода
    for i in set(data['pclass']):
        sns.relplot(x = 'fare' , y ='age', hue = 'alive', hue_order = ['yes', 'no'],data = data[data['pclass'] == i],
                   height = 4, aspect = 8/4)
        plt.title(f'Passenger class: {i}')
    #Конец вашего кода

plot_sns_pclass(data=titanic)

# %% [markdown]
# ### Ожидаемый результат:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Шаг 5
#
#
# Пожалуйста, реализуйте функцию ```plot_sns_sex(data=None)```, которая отображает несколько фигур, каждая фигура содержит визуализацию на основе пола пассажира.
#
# **Замечания: высота фигуры = 4 и ширина фигуры = 8**

# %%
def plot_sns_sex(data=None):
    #Начало вашего кода
    for i in set(data['sex']):
        sns.relplot(x = 'fare', y = 'age',data = data[data['sex'] == i], hue = 'alive',hue_order = ['yes', 'no'],
                   height = 4, aspect = 8/4)
        plt.title(f'Passenger sex : {i}')
    #Конец вашего кода

plot_sns_sex(data=titanic)

# %% [markdown]
# ### Ожидаемый результат:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Шаг 6
#
#
# Пожалуйста, реализуйте функцию ```plot_sns_town(data=None)```, которая отображает несколько фигур, каждая фигура содержит визуализацию на основе города пассажира.
#
# **Замечания: высота фигуры = 4 и ширина фигуры = 8**

# %%
def plot_sns_town(data=None):
    #Начало вашего кода
    for i in set(data['embark_town'].dropna()):
        sns.relplot(x = 'fare', y = 'age', data = data[data['embark_town'] == i], hue = 'alive', hue_order = ['yes','no'],
                   height = 4, aspect = 8/4)
        plt.title(f'Passanger town {i}')
    #Конец вашего кода

plot_sns_town(data=titanic)

# %% [markdown]
# ### Ожидаемый результат:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Шаг 7
#
# Сделайте фигуру, как показано ниже (высота фигуры = 7 и ширина фигуры = 10.5)
#
# ![image.png](attachment:image.png)

# %%
#Начало вашего кода
sns.set_context('talk')
sns.relplot(x = 'age', y = 'fare', data = titanic, size = 'pclass', sizes =(50,150) , hue = 'sex', style = 'alive',
            style_order = ['yes' , 'no'] , height = 7, aspect = 10.5/7);
#Конец вашего кода

# %% [markdown]
# ### Шаг 8
#
# Ответьте на следующие вопросы:
#
# 1. Какая связь между параметрами "age","alive"?
#
# 2. Какая связь между параметрами "fare","alive"?
#
# 3. Какая связь между параметрами "pclass","alive"?
#
# 4. Какая связь между параметрами "sex","alive"?
#
# 5. Какая связь между параметрами "town","fare"?
#
# 6. Какая связь между параметрами "town","alive"?

# %% [markdown]
# Ответ
# 1. Во всей пассажирский классах у молодых людей больше шансов выжить чем у взрослых. Если человек моложе 15-20 лет, то у него намного больше шансов выжить, особенно в 1 и 2 классах. Люди старше 60 имеет меньшие шансы.
# 2. Транспортные расходы тоже влияют на шансы выжить. Чем больше цена, тем больше шанс выжить. Люди кот заплатили 500+ все выжили. Если человек заплатил более 50 или 100 то у него высокие шансы выжить. У людей заплативших менее 15-30 они малы. Особенно те кто заплатил менее 10.
# 3. Чем выше класс , тем больше выживших.  В 1 классе выглядит, что большинство выжило, в 2 примерно поравно и в 3 явно больше не выжило.
# 4. Женщин выжило на много больше чем мужчин. Это объясняется правилом, что женщины и дети спасаются в первую очередь.
# 5. 'fare' явно отличается по городам. Из Cherbourg самые состоятельные люди, только из этого города есть люди кот заплатили 500+. Большинство заплатило 0-150 что выше других. В Queenstown меньше всего людей и они заплатили тоже мало, 0-30. Из Southampton больше всего людей. большинство заплатили 0-100.
# 6. "alive" различается по городам. В Cherbourg больше всего вероятности выжить, это также можно объяснить, то что они больше всего платили. Мы уже выяснили что "fare" вляет на выживание. Также из Queenston меньше всего выживших. В Southampton выживших меньше чем в Cherbourg, больше выживаемость зависит от других факторов как возраст или 'fare'

# %% [markdown]
# # Прекрасная работа!
