# %% [markdown]
# ### Теория вероятности-2 [Домашнее задание]

# %% [markdown]
# **Примечание:**
#
# > Пожалуйста, не удаляйте комментарии или строки кода.
#
# > Вы можете использовать пакеты ```NumPy```, ```matplotlib```.
#
# > Пожалуйста, покажите ваше решение, написав процедуру расчета.
#
# **Например:**
#
# Если вы подбросите монету, какова вероятность получить Tails?
#
# **Ваше решение должно выглядеть так:**
#
# ```
# p_tails = 1 / (2**1) # Хороший пример решения
# # p_tails = 0.5 # Плохой пример решения
# ```
#
# **Игральная кость:**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. Решите вопросы, связанные с теорией вероятности, приведенные ниже:
#
#     * Мы бросаем монету 3 раза, какова вероятность выпасть 1 ```Heads``` и 2 ```Tails```? Присвойте результат переменной ```p_three_flips```.
#
#     * Мы бросаем монету 4 раза, какова вероятность выпасть 3 ```Heads``` и 1 ```Tails```? Присвойте результат переменной ```p_four_flips```.
#
#     * Мы бросаем монету 5 раз, какова вероятность выпасть 2 ```Heads``` и 3 ```Tails```? Присвойте результат переменной ```p_five_flips```.

# %%
#Начало вашего кода
p_three_flips = 3/(2**3)
p_four_flips = 4/(2**4)
p_five_flips = 10/(2**5)
#Конец вашего кода
print(f"{p_three_flips*100:.2f} %")
print(f"{p_four_flips*100:.2f} %")
print(f"{p_five_flips*100:.2f} %")
# Out:
# 37.50 %
# 25.00 %
# 31.25 %

# %% [markdown]
# ### Ожидаемые результаты:
#
# ```
# 37.50 %
# 25.00 %
# 31.25 %
# ```

# %% [markdown]
# 2. Решите вопросы, связанные с теорией вероятности, приведенные ниже:
#
#     * Мы бросаем игральную кость 3 раза, какова вероятность выпасть ```{1,1,2}```? Присвойте результат переменной ```p_three_rolls```.
#
#     * Мы бросаем игральную кость 4 раза, какова вероятность выпасть ```{2,2,3,4}```? Присвойте результат переменной ```p_four_rolls```.
#
#     * Мы бросаем игральную кость 5 раз, какова вероятность выпасть ```{1,2,3,4,5}```? Присвойте результат переменной ```p_five_rolls```.

# %%
#Начало вашего кода
p_three_rolls = 3/(6**3)
p_four_rolls = 12/(6**4)
p_five_rolls = 120/(6**5)


#Конец вашего кода
print(f"{p_three_rolls*100:.2f} %")
print(f"{p_four_rolls*100:.2f} %")
print(f"{p_five_rolls*100:.2f} %")
# Out:
# 1.39 %
# 0.93 %
# 1.54 %

# %% [markdown]
# ### Ожидаемые результаты:
#
# ```
# 1.39 %
# 0.93 %
# 1.54 %
# ```

# %% [markdown]
# 3. Давайте бросим монету один раз и бросим игральную кость один раз. Пожалуйста, ответьте на следующие вопросы:
#
#     * Какова вероятность того, что выпадет ```Heads``` и число ```3```? Присвойте результат переменной ```p_heads_3```.
#
#     * Какова вероятность того, что выпадет ```Heads``` и число ```2```? Присвойте результат переменной ```p_heads_2```.
#
#     * Какова вероятность того, что выпадет ```Heads``` и число ```0```? Присвойте результат переменной ```p_heads_0```.
#
#     * Какова вероятность того, что выпадет ```Tails``` и ```нечетное``` число? Присвойте результат переменной ```p_tails_odd```.
#
#     * Какова вероятность того, что выпадет ```Heads``` и число ```больше 4```? Присвойте результат переменной ```p_heads_larger_4```.

# %%
#Начало вашего кода
p_heads_3 = 1/(2 * 6)
p_heads_2 = 1/ (2 * 6 )
p_heads_0 = 0/ (2 * 6)
p_tails_odd = 3 / (2*6)
p_heads_larger_4 = 2 / (2*6)

#Конец вашего кода
print(f"вероятность того, что выпадет Heads и число 3: {p_heads_3*100:.2f} %")
print(f"вероятность того, что выпадет Heads и число 2: {p_heads_2*100:.2f} %")
print(f"вероятность того, что выпадет Heads и число 0: {p_heads_0*100:.2f} %")
print(f"вероятность того, что выпадет Tails и нечетное число: {p_tails_odd*100:.2f} %")
print(f"вероятность того, что выпадет Heads и число больше 4: {p_heads_larger_4*100:.2f} %")
# Out:
# вероятность того, что выпадет Heads и число 3: 8.33 %
# вероятность того, что выпадет Heads и число 2: 8.33 %
# вероятность того, что выпадет Heads и число 0: 0.00 %
# вероятность того, что выпадет Tails и нечетное число: 25.00 %
# вероятность того, что выпадет Heads и число больше 4: 16.67 %

# %% [markdown]
# ### Ожидаемые результаты:
#
# ```
# вероятность того, что выпадет Heads и число 3: 8.33 %
# вероятность того, что выпадет Heads и число 2: 8.33 %
# вероятность того, что выпадет Heads и число 0: 0.00 %
# вероятность того, что выпадет Tails и нечетное число: 25.00 %
# вероятность того, что выпадет Heads и число больше 4: 16.67 %
# ```

# %% [markdown]
# 4. Решите вопросы, связанные с теорией вероятности, приведенные ниже:
#
#     * В магазине вероятность того, что покупатель купит молоко, равна ```0.4```; вероятность того, что шоколад - ```0.32```; а вероятность того, что купит молоко и шоколад - ```0.1```. Какова вероятность того, что покупатель молоко или шоколад? Присвойте результат переменной ```p_milk_or_bread```.
#
#     * На основании исторических данных в банке, человек, увидев рекламу банка, откроет новый счет с вероятностью ```0.23```. Какова вероятность того, что человек проигнорирует рекламу? Присвойте результат переменной ```p_bank_adv```.
#
#     * Маркетинговая компания оценила следующие вероятности: человек нажимает на рекламу A - ```0.35```, человек нажимает на рекламу B - ```0.27```, человек нажимает на рекламу A или B - ```0.48```. Какова вероятность того, что человек нажмет на обе рекламы? Присвойте результат переменной ```p_a_b```. Какова вероятность того, что человек проигнорирует обе рекламы? Присвойте результат переменной ```p_no```

# %%
#Начало вашего кода
p_milk_or_bread = 0.4 + 0.32 - 0.1
p_bank_adv = 1 - 0.23 
p_a_b = 0.35 + 0.27 - 0.48
p_no = 1 - 0.48 
#Конец вашего кода
print(f"вероятность того, что покупатель купит молоко или шоколад: {p_milk_or_bread*100:.2f} %")
print(f"вероятность того, что человек проигнорирует рекламу: {p_bank_adv*100:.2f} %")
print(f"вероятность того, что человек нажмет на обе рекламы: {p_a_b*100:.2f} %")
print(f"вероятность того, что человек проигнорирует обе рекламы: {p_no*100:.2f} %")
# Out:
# вероятность того, что покупатель купит молоко или шоколад: 62.00 %
# вероятность того, что человек проигнорирует рекламу: 77.00 %
# вероятность того, что человек нажмет на обе рекламы: 14.00 %
# вероятность того, что человек проигнорирует обе рекламы: 52.00 %

# %% [markdown]
# ### Ожидаемые результаты:
#
# ```
# вероятность того, что покупатель купит молоко или шоколад: 62.00 %
# вероятность того, что человек проигнорирует рекламу: 77.00 %
# вероятность того, что человек нажмет на обе рекламы: 14.00 %
# вероятность того, что человек проигнорирует обе рекламы: 52.00 %
# ```

# %% [markdown]
# 5. Давайте бросим игральную кость дважды. Вы получите два числа. Пожалуйста, ответьте на следующие вопросы:
#
#     * Какова вероятность того, что сумма двух чисел будет 1? Присвойте результат переменной ```p_1```.
#
#     * Какова вероятность того, что сумма двух чисел будет 20? Присвойте результат переменной ```p_20```.
#
#     * Какова вероятность того, что сумма двух чисел будет меньше 7? Присвойте результат переменной ```p_less_7```.
#
#     * Какова вероятность того, что сумма двух чисел будет больше 5? Присвойте результат переменной ```p_larger_5```.
#
#     * Какова вероятность того, что абсолютная разница двух чисел будет 0? Присвойте результат переменной ```p_0```.
#
#     * Какова вероятность того, что произведение двух чисел будет меньше 15? Присвойте результат переменной ```p_less_15```.
#
#     * Какова вероятность того, что произведение двух чисел будет больше 20? Присвойте результат переменной ```p_larger_20```.
#
#     * Какова вероятность того, что произведение двух чисел будет четным? Присвойте результат переменной ```p_even```.
#
#     * Какова вероятность того, что сумма двух чисел будет нечетным? Присвойте результат переменной ```p_odd```.
#
#     * Какова вероятность того, что сумма в два раза больше чем абсолютная разница двух чисел? Присвойте результат переменной ```p_sum_diff```.
#
#     * Какова вероятность того, что сумма и произведение двух чисел равны друг другу? Присвойте результат переменной ```p_sum_prod```.
#
#
#
# **Подсказка:** вам может понадобиться построить пространства элементарных исходов.

# %%
import numpy as np

# %%
sum2x = np.transpose(np.array([1,2,3,4,5,6]) * np.ones((6,6))) + np.array([1,2,3,4,5,6])
sum2x
# Out:
# array([[ 2.,  3.,  4.,  5.,  6.,  7.],
#        [ 3.,  4.,  5.,  6.,  7.,  8.],
#        [ 4.,  5.,  6.,  7.,  8.,  9.],
#        [ 5.,  6.,  7.,  8.,  9., 10.],
#        [ 6.,  7.,  8.,  9., 10., 11.],
#        [ 7.,  8.,  9., 10., 11., 12.]])

# %%
prod = (np.transpose(np.ones((6,6)) * np.array([1,2,3,4,5,6]))) * np.array([1,2,3,4,5,6])# Таблица произведений 
prod
# Out:
# array([[ 1.,  2.,  3.,  4.,  5.,  6.],
#        [ 2.,  4.,  6.,  8., 10., 12.],
#        [ 3.,  6.,  9., 12., 15., 18.],
#        [ 4.,  8., 12., 16., 20., 24.],
#        [ 5., 10., 15., 20., 25., 30.],
#        [ 6., 12., 18., 24., 30., 36.]])

# %%
#Начало вашего кода
p_1 = (sum2x == 1).sum()/36
p_20 = (sum2x == 20).sum()/36
p_less_7 = (sum2x < 7).sum()/36
p_larger_5 = (sum2x > 5).sum()/36
p_0 = 6 / 36
p_less_15 = (prod < 15).sum() / 36
p_larger_20 = (prod > 20).sum() / 36
p_even = (prod % 2 == 0).sum() / 36
p_odd = (sum2x % 2 != 0).sum()/36
p_sum_diff = 4 / 36
p_sum_prod = (sum2x == prod).sum()/ 36
#Конец вашего кода
print(f"вероятность того, что сумма двух чисел будет 1: {p_1*100:.2f} %")
print(f"вероятность того, что сумма двух чисел будет 20: {p_20*100:.2f} %")
print(f"вероятность того, что сумма двух чисел будет меньше 7: {p_less_7*100:.2f} %")
print(f"вероятность того, что сумма двух чисел будет больше 5: {p_larger_5*100:.2f} %")
print(f"вероятность того, что абсолютная разница двух чисел будет 0: {p_0*100:.2f} %")
print(f"вероятность того, что произведение двух чисел будет меньше 15: {p_less_15*100:.2f} %")
print(f"вероятность того, что произведение двух чисел будет больше 20: {p_larger_20*100:.2f} %")
print(f"вероятность того, что произведение двух чисел будет четным: {p_even*100:.2f} %")
print(f"вероятность того, что сумма двух чисел будет нечетным: {p_odd*100:.2f} %")
print(f"вероятность того, что сумма в два раза больше чем абсолютная разница двух чисел: {p_sum_diff*100:.2f} %")
print(f"вероятность того, что сумма и произведение двух чисел равны друг другу: {p_sum_prod*100:.2f} %")
# Out:
# вероятность того, что сумма двух чисел будет 1: 0.00 %
# вероятность того, что сумма двух чисел будет 20: 0.00 %
# вероятность того, что сумма двух чисел будет меньше 7: 41.67 %
# вероятность того, что сумма двух чисел будет больше 5: 72.22 %
# вероятность того, что абсолютная разница двух чисел будет 0: 16.67 %
# вероятность того, что произведение двух чисел будет меньше 15: 63.89 %
# вероятность того, что произведение двух чисел будет больше 20: 16.67 %
# вероятность того, что произведение двух чисел будет четным: 75.00 %
# вероятность того, что сумма двух чисел будет нечетным: 50.00 %
# вероятность того, что сумма в два раза больше чем абсолютная разница двух чисел: 11.11 %
# вероятность того, что сумма и произведение двух чисел равны друг другу: 2.78 %

# %% [markdown]
# ### Ожидаемые результаты:
#
# ```
# вероятность того, что сумма двух чисел будет 1: 0.00 %
# вероятность того, что сумма двух чисел будет 20: 0.00 %
# вероятность того, что сумма двух чисел будет меньше 7: 41.67 %
# вероятность того, что сумма двух чисел будет больше 5: 72.22 %
# вероятность того, что абсолютная разница двух чисел будет 0: 16.67 %
# вероятность того, что произведение двух чисел будет меньше 15: 63.89 %
# вероятность того, что произведение двух чисел будет больше 20: 16.67 %
# вероятность того, что произведение двух чисел будет четным: 75.00 %
# вероятность того, что сумма двух чисел будет нечетным: 50.00 %
# вероятность того, что сумма в два раза больше чем абсолютная разница двух чисел: 11.11 %
# вероятность того, что сумма и произведение двух чисел равны друг другу: 2.78 %
# ```

# %% [markdown]
# 6. Давайте бросим игральную кость трижды. Вы получите три числа. Пожалуйста, ответьте на следующие вопросы:
#
#     * Какова вероятность того, что сумма трех чисел будет 1? Присвойте результат переменной ```p3_1```.
#
#     * Какова вероятность того, что сумма трех чисел будет 20? Присвойте результат переменной ```p3_20```.
#
#     * Какова вероятность того, что сумма трех чисел будет меньше 7? Присвойте результат переменной ```p3_less_7```.
#
#     * Какова вероятность того, что сумма трех чисел будет больше 5? Присвойте результат переменной ```p3_larger_5```.
#
#     * Какова вероятность того, что произведение трех чисел будет меньше 15? Присвойте результат переменной ```p3_less_15```.
#
#     * Какова вероятность того, что произведение трех чисел будет больше 20? Присвойте результат переменной ```p3_larger_20```.
#
#     * Какова вероятность того, что произведение трех чисел будет четным? Присвойте результат переменной ```p3_even```.
#
#     * Какова вероятность того, что сумма трех чисел будет нечетным? Присвойте результат переменной ```p3_odd```.
#
#     * Какова вероятность того, что сумма и произведение трех чисел равны друг другу? Присвойте результат переменной ```p3_sum_prod```.
#
# **Подсказка:** вам может понадобиться построить пространства элементарных исходов.

# %%
sum3x = np.transpose(np.ones((6,6,6)) * sum2x) + np.array([1,2,3,4,5,6])
sum3x
# Out:
# array([[[ 3.,  4.,  5.,  6.,  7.,  8.],
#         [ 4.,  5.,  6.,  7.,  8.,  9.],
#         [ 5.,  6.,  7.,  8.,  9., 10.],
#         [ 6.,  7.,  8.,  9., 10., 11.],
#         [ 7.,  8.,  9., 10., 11., 12.],
#         [ 8.,  9., 10., 11., 12., 13.]],
#
#        [[ 4.,  5.,  6.,  7.,  8.,  9.],
#         [ 5.,  6.,  7.,  8.,  9., 10.],
#         [ 6.,  7.,  8.,  9., 10., 11.],
#         [ 7.,  8.,  9., 10., 11., 12.],
#         [ 8.,  9., 10., 11., 12., 13.],
#         [ 9., 10., 11., 12., 13., 14.]],
#
#        [[ 5.,  6.,  7.,  8.,  9., 10.],
#         [ 6.,  7.,  8.,  9., 10., 11.],
#         [ 7.,  8.,  9., 10., 11., 12.],
#         [ 8.,  9., 10., 11., 12., 13.],
#         [ 9., 10., 11., 12., 13., 14.],
#         [10., 11., 12., 13., 14., 15.]],
#
#        [[ 6.,  7.,  8.,  9., 10., 11.],
#         [ 7.,  8.,  9., 10., 11., 12.],
#         [ 8.,  9., 10., 11., 12., 13.],
#         [ 9., 10., 11., 12., 13., 14.],
#         [10., 11., 12., 13., 14., 15.],
# ...

# %%
prod3x = np.transpose((np.ones((6,6,6)) * prod) )* np.array([1,2,3,4,5,6])
prod3x
# Out:
# array([[[  1.,   2.,   3.,   4.,   5.,   6.],
#         [  2.,   4.,   6.,   8.,  10.,  12.],
#         [  3.,   6.,   9.,  12.,  15.,  18.],
#         [  4.,   8.,  12.,  16.,  20.,  24.],
#         [  5.,  10.,  15.,  20.,  25.,  30.],
#         [  6.,  12.,  18.,  24.,  30.,  36.]],
#
#        [[  2.,   4.,   6.,   8.,  10.,  12.],
#         [  4.,   8.,  12.,  16.,  20.,  24.],
#         [  6.,  12.,  18.,  24.,  30.,  36.],
#         [  8.,  16.,  24.,  32.,  40.,  48.],
#         [ 10.,  20.,  30.,  40.,  50.,  60.],
#         [ 12.,  24.,  36.,  48.,  60.,  72.]],
#
#        [[  3.,   6.,   9.,  12.,  15.,  18.],
#         [  6.,  12.,  18.,  24.,  30.,  36.],
#         [  9.,  18.,  27.,  36.,  45.,  54.],
#         [ 12.,  24.,  36.,  48.,  60.,  72.],
#         [ 15.,  30.,  45.,  60.,  75.,  90.],
#         [ 18.,  36.,  54.,  72.,  90., 108.]],
#
#        [[  4.,   8.,  12.,  16.,  20.,  24.],
#         [  8.,  16.,  24.,  32.,  40.,  48.],
# ...

# %%
#Начало вашего кода
#Начало вашего кода
p_1 = 0/216
p_20 = 0/216
p_less_7 = (sum3x < 7).sum()/216
p_larger_5 = (sum3x > 5).sum()/216
p_less_15 = (prod3x < 15).sum() / 216
p_larger_20 = (prod3x > 20).sum()/ 216
p_even = (prod3x % 2 == 0).sum() / 216
p_odd = (sum3x % 2 != 0).sum()/216
p_sum_prod = (sum3x == prod3x).sum()/ 216
#Конец вашего кода
print(f"вероятность того, что сумма трех чисел будет 1: {p_1*100:.2f} %")
print(f"вероятность того, что сумма трех чисел будет 20: {p_20*100:.2f} %")
print(f"вероятность того, что сумма трех чисел будет меньше 7: {p_less_7*100:.2f} %")
print(f"вероятность того, что сумма трех чисел будет больше 5: {p_larger_5*100:.2f} %")
print(f"вероятность того, что произведение трех чисел будет меньше 15: {p_less_15*100:.2f} %")
print(f"вероятность того, что произведение трех чисел будет больше 20: {p_larger_20*100:.2f} %")
print(f"вероятность того, что произведение трех чисел будет четным: {p_even*100:.2f} %")
print(f"вероятность того, что сумма трех чисел будет нечетным: {p_odd*100:.2f} %")
print(f"вероятность того, что сумма и произведение двух чисел равны друг другу: {p_sum_prod*100:.2f} %")
#Конец вашего кода
# Out:
# вероятность того, что сумма трех чисел будет 1: 0.00 %
# вероятность того, что сумма трех чисел будет 20: 0.00 %
# вероятность того, что сумма трех чисел будет меньше 7: 9.26 %
# вероятность того, что сумма трех чисел будет больше 5: 95.37 %
# вероятность того, что произведение трех чисел будет меньше 15: 25.93 %
# вероятность того, что произведение трех чисел будет больше 20: 60.19 %
# вероятность того, что произведение трех чисел будет четным: 87.50 %
# вероятность того, что сумма трех чисел будет нечетным: 50.00 %
# вероятность того, что сумма и произведение двух чисел равны друг другу: 2.78 %

# %% [markdown]
# ### Ожидаемые результаты:
#
# ```
# вероятность того, что сумма трех чисел будет 1: 0.00 %
# вероятность того, что сумма трех чисел будет 20: 0.00 %
# вероятность того, что сумма трех чисел будет меньше 7: 9.26 %
# вероятность того, что сумма трех чисел будет больше 5: 95.37 %
# вероятность того, что произведение трех чисел будет меньше 15: 25.93 %
# вероятность того, что произведение трех чисел будет больше 20: 60.19 %
# вероятность того, что произведение трех чисел будет четным: 87.50 %
# вероятность того, что сумма трех чисел будет нечетным: 50.00 %
# вероятность того, что сумма и произведение трех чисел равны друг другу: 2.78 %
# ```

# %% [markdown]
# ### Отличная работа
