# %% [markdown]
# ### Дерево принятия решения [Домашнее задание]

# %% [markdown]
# **Примечание:**
#
# > Пожалуйста, не удаляйте комментарии или строки кода.

# %% [markdown]
# 1. Пожалуйста, реализуйте функцию ```load_data(filename=None)```, которая будет загружать данные файла csv из ```filename``` и возвращать ```DataFrame```.

# %%
import pandas as pd

def load_data(filename=None):
    #Начало вашего кода
    return pd.read_csv(filename)

    #Конец вашего кода

num_data = load_data(filename="num_house_prices.csv")
num_data
# Out:
#         Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0        1          60     8450            7            5       2003
# 1        2          20     9600            6            8       1976
# 2        3          60    11250            7            5       2001
# 3        4          70     9550            7            5       1915
# 4        5          60    14260            8            5       2000
# ...    ...         ...      ...          ...          ...        ...
# 1333  1456          60     7917            6            5       1999
# 1334  1457          20    13175            6            6       1978
# 1335  1458          70     9042            7            9       1941
# 1336  1459          20     9717            5            6       1950
# 1337  1460          20     9937            5            6       1965
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  WoodDeckSF  \
# ...

# %% [markdown]
# ### Ожидаемые результаты:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. Пожалуйста, реализуйте функцию ```split_data(data, ratio=0.1)```, которая разбивает набор данных, загруженный в предыдущем вопросе, на наборы данных ```train``` и ```validation``` в соотношении 9:1.

# %%
import numpy as np

def split_data(data, ratio=0.1):
    np.random.seed(1)
    #Начало вашего кода    
    indeces = np.arange(0,len(data))
    np.random.shuffle(indeces)
    val_ind = indeces[: round(ratio * len(indeces))]
    train_ind = indeces[round(ratio * len(indeces)):]
    val_data = data.loc[val_ind]
    train_data = data.loc[train_ind]
    #Конец вашего кода
    return {"validation":val_data, "train":train_data}

splitted_data = split_data(num_data, ratio=0.1)

# %%
splitted_data["validation"].head()
# Out:
#         Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  \
# 559    610          20     7943            4            5       1961
# 1087  1189          60     8935            7            5       2002
# 1020  1116          20    12085            8            5       2007
# 460    502          60     9803            7            5       2005
# 802    873          20     8892            5            7       1953
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  WoodDeckSF  \
# 559           1961       192.0         903           0  ...          64
# 1087          2002        95.0           0           0  ...         144
# 1020          2007       328.0        1004           0  ...           0
# 460           2005         0.0         400           0  ...           0
# 802           1996         0.0           0           0  ...         196
#
#       OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# ...

# %% [markdown]
# ### Ожидаемые результаты:
#
# ![image.png](attachment:image.png)

# %%
splitted_data["train"].head()
# Out:
#         Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  \
# 355    390          60    12474           10            5       2007
# 1316  1436          20     8400            6            9       1962
# 133    147          30     6120            5            7       1931
# 181    202          20    10125            6            6       1977
# 1133  1240          20     9037            8            5       2006
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  WoodDeckSF  \
# 355           2008       272.0        1280           0  ...         196
# 1316          2005       237.0           0           0  ...           0
# 133           1993         0.0         209           0  ...          48
# 181           1977         0.0         641         279  ...         238
# 1133          2006        32.0         428           0  ...         120
#
#       OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# ...

# %% [markdown]
# ### Ожидаемые результаты:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. Пожалуйста, визуализируйте коэффициенты корреляции для набора данных ```train```.
#
# Примечание: ```figsize=(10,8)```

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#Начало вашего кода 
plt.figure(figsize=(10,8))
sns.heatmap(splitted_data["train"].corr());
#Конец вашего кода

# %% [markdown]
# ### Ожидаемые результаты:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 4. Теперь выберите топ 9 наиболее коррелированных параметров с ```"SalePrice"``` и назначьте результаты списку ```important```. Теперь визуализируйте коэффициенты корреляции этих параметров (переменных).
#
#     Примечание: ```figsize=(8,8)```

# %%
#Начало вашего кода 
plt.figure(figsize=(10,8))
most_corr = splitted_data["train"].corr()['SalePrice'].sort_values(ascending = False)[0:10].index
important = most_corr[1:]
sns.heatmap(splitted_data["train"][most_corr].corr(), annot = True);
#Конец вашего кода

# %% [markdown]
# ### Ожидаемые результаты:
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 5. Теперь пришло время использовать дерево принятия решения (регрессии) для параметров в списке ```important``` для прогнозирования ```SalePrice```. Пожалуйста, реализуйте функцию ```train_decision_tree_regressor(data, parameters, target="SalePrice", degree=1, random_state=0)```, которая будет обучать дерево принятия решения (регрессии) для параметров из списка ```parameters```. Функция должна возвращать словарь с обученным деревом принятия решения (регрессии), списком ```parameters```.

# %%
#Начало вашего кода 
def train_decision_tree_regressor(data, parameters, target="SalePrice", degree=1, random_state=0):
    from sklearn.tree import DecisionTreeRegressor 
    regressor = DecisionTreeRegressor(random_state = random_state)
    regressor.fit(data[parameters].values, data[target])
    d = {}
    d['regressor'] = regressor
    d['parameters'] = parameters
    return d
#Конец вашего код
model = train_decision_tree_regressor(splitted_data["train"], important, target="SalePrice")
print(model)
# Out:
# {'regressor': DecisionTreeRegressor(random_state=0), 'parameters': Index(['OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea', '1stFlrSF',
#        'TotalBsmtSF', 'FullBath', 'TotRmsAbvGrd', 'YearRemodAdd'],
#       dtype='object')}

# %% [markdown]
# ### Ожидаемые результаты:
#
# ```python
# {'regressor': DecisionTreeRegressor(random_state=0), 'parameters': Index(['OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea', '1stFlrSF',
#        'TotalBsmtSF', 'FullBath', 'TotRmsAbvGrd', 'YearRemodAdd'],
#       dtype='object')}
# ```

# %% [markdown]
# 6. Пожалуйста, реализуйте функцию ```validation(model, data, target="SalePrice")```, которая будет принимать словарь ```model```, данные ```validation``` и параметр ```target```, который должен быть предсказан. Функция должна возвращать ```DataFrame``` с первым столбцом, который будет истинным ```"SalePrice"```,  а второй столбец предсказан деревом принятия решения и ```rmse```.

# %%
#Начало вашего кода
def validation(model, data, target="SalePrice"):
    df = pd.DataFrame()
    pred = model['regressor'].predict(data[model['parameters']].values)
    df['True Sale Price'] = data['SalePrice']
    df['Predicted Sale Price'] = pred
    rmse = rmse = (np.mean(( data['SalePrice']- pred)**2)) **0.5
    return df, rmse
#Конец вашего кода

# %% [markdown]
# 7. Спрогнозируйте ```"SalePrice"``` для набора данных ```train``` с использованием дерева принятия решения (регрессии). Кроме того, выполните визуализацию прогнозируемого и истинного SalePrice.
#
# **Примечание:** figsize=(8,8)

# %%
#Начало вашего кода
df , rmse = validation(model,splitted_data["train"], target="SalePrice" )
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize = (8,8))
sns.set_context('notebook');
sns.scatterplot(x = df['True Sale Price'], y = df['Predicted Sale Price'] );
plt.title(f'Train dataset rmse {round(rmse, 2)} USD');
#Конец вашего кода

# %% [markdown]
# ### Ожидаемые результаты:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 8. Спрогнозируйте ```"SalePrice"``` для набора данных ```validation``` с использованием дерева принятия решения (регрессии). Кроме того, выполните визуализацию прогнозируемого и истинного SalePrice.
#
# **Примечание:** figsize=(8,8)

# %%
#Начало вашего кода
df , rmse = validation(model,splitted_data["validation"], target="SalePrice" )
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize = (8,8))
sns.set_context('notebook');
sns.scatterplot(x = df['True Sale Price'], y = df['Predicted Sale Price'] );
plt.title(f'Train dataset rmse {round(rmse, 2)} USD');
#Конец вашего кода

# %% [markdown]
# ### Ожидаемые результаты:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 9. Что вы думаете о такой большой разнице в ```rmse``` для набора данных ```train``` и ```validation```?

# %%
#Начало вашего кода
# Модель обучалась на данных train, поэтому я думаю такая разница. 
# Также в train данных больше, поэтому модель дает более точный результат
#Конец вашего кода

# %% [markdown]
# ### Отличная работа
