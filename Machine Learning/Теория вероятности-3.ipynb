# %% [markdown]
# ### Теория вероятности-3 [Домашнее задание]

# %% [markdown]
# **Примечание:**
#
# > Пожалуйста, не удаляйте комментарии или строки кода.
#
# > Вы можете использовать пакеты ```NumPy```, ```matplotlib```.
#
# > Пожалуйста, покажите ваше решение, написав процедуру расчета.
#
# **Например:**
#
# Если вы подбросите монету, какова вероятность получить Tails?
#
# **Ваше решение должно выглядеть так:**
#
# ```
# p_tails = 1 / (2**1) # Хороший пример решения
# # p_tails = 0.5 # Плохой пример решения
# ```
#
# **Игральная кость:**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. Решите вопросы, связанные с теорией вероятности, приведенные ниже:
#
#     * Какова вероятность, что для получения ```Tails``` понадобится ровно три броска монеты? Присвойте результат переменной ```p_tails_3```.
#
#     * Какова вероятность, что для получения ```Heads``` понадобится не менее пяти бросков монеты? Присвойте результат переменной ```p_heads_least_5```.
#
#     * Какова вероятность, что для получения ```3``` понадобится ровно четыре броска игральной кости? Присвойте результат переменной ```p_3_4```.
#     * Какова вероятность, что для получения ```6``` понадобится не менее трех бросков игральной кости? Присвойте результат переменной ```p_6_least_3```.
#
# **Внимание:** "ровно 3 броска монеты / игральной кости означает", что только на третьем броске мы получим желаемый результат.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Начало вашего кода
p_tails_3 = 1/8
p_heads_least_5 = 1 - (0.5 + 0.25 + 0.125 + 0.0625)
p_3_4 = 125/6**4
p_6_least_3 =(5/6) * (5/6)
#Конец вашего кода
print(f'вероятность, что для получения Tails понадобится ровно три броска монеты: {p_tails_3*100:.2f} %')
print(f'вероятность, что для получения Heads понадобится не менее пяти бросков монеты: {p_heads_least_5*100:.2f} %')
print(f'вероятность, что для получения 3 понадобится ровно четыре броска игральной кости: {p_3_4*100:.2f} %')
print(f'вероятность, что для получения 6 понадобится не менее трех бросков игральной кости: {p_6_least_3*100:.2f} %')
# Out:
# вероятность, что для получения Tails понадобится ровно три броска монеты: 12.50 %
# вероятность, что для получения Heads понадобится не менее пяти бросков монеты: 6.25 %
# вероятность, что для получения 3 понадобится ровно четыре броска игральной кости: 9.65 %
# вероятность, что для получения 6 понадобится не менее трех бросков игральной кости: 69.44 %

# %% [markdown]
# ### Ожидаемые результаты:
#
# ```
# вероятность, что для получения Tails понадобится ровно три броска монеты: 12.50 %
# вероятность, что для получения Heads понадобится не менее пяти бросков монеты: 6.25 %
# вероятность, что для получения 3 понадобится ровно четыре броска игральной кости: 9.65 %
# вероятность, что для получения 6 понадобится не менее трех бросков игральной кости: 69.44 %
# ```

# %% [markdown]
# 2. Бросая монету, ответьте на вопросы приведенные ниже:
#
#     * Какова вероятность того, что мы получим (```Heads```,```Tails```), именно в этом порядке? Присвойте результат переменной ```p_ht```.
#
#     * Какова вероятность того, что мы получим (```Heads```,```Heads```,```Tails```), именно в этом порядке? Присвойте результат переменной ```p_hht```.
#
#     * Какова вероятность того, что мы получим (```Tails```,```Tails```,```Tails```), именно в этом порядке? Присвойте результат переменной ```p_ttt```.
#
#     * Какова вероятность того, что мы получим (```Heads```,```Tails```,```Tails```,```Heads```), именно в этом порядке? Присвойте результат переменной ```p_htth```.
#
#     * Какова вероятность того, что мы получим (```Tails```,```Heads```,```Tails```,```Heads```,```Heads```), именно в этом порядке? Присвойте результат переменной ```p_ththh```.

# %%
#Начало вашего кода
p_ht = 1/2**2 # т.к всего возможных результатов 4 и только 1 нам подходит 
p_hht = 1/2**3
p_ttt = 1/2**3
p_htth = 1/2**4
p_ththh = 1/2**5

#Конец вашего кода
print(f'вероятность того, что мы получим (Heads,Tails), именно в этом порядке: {p_ht*100:.2f} %')
print(f'вероятность того, что мы получим (Heads,Heads,Tails), именно в этом порядке: {p_hht*100:.2f} %')
print(f'вероятность того, что мы получим (Tails,Tails,Tails), именно в этом порядке: {p_ttt*100:.2f} %')
print(f'вероятность того, что мы получим (Heads,Tails,Tails,Heads), именно в этом порядке: {p_htth*100:.2f} %')
print(f'вероятность того, что мы получим (Tails,Heads,Tails,Heads,Heads), именно в этом порядке: {p_ththh*100:.2f} %')
# Out:
# вероятность того, что мы получим (Heads,Tails), именно в этом порядке: 25.00 %
# вероятность того, что мы получим (Heads,Heads,Tails), именно в этом порядке: 12.50 %
# вероятность того, что мы получим (Tails,Tails,Tails), именно в этом порядке: 12.50 %
# вероятность того, что мы получим (Heads,Tails,Tails,Heads), именно в этом порядке: 6.25 %
# вероятность того, что мы получим (Tails,Heads,Tails,Heads,Heads), именно в этом порядке: 3.12 %

# %% [markdown]
# ### Ожидаемые результаты:
#
# ```
# вероятность того, что мы получим (Heads,Tails), именно в этом порядке: 25.00 %
# вероятность того, что мы получим (Heads,Heads,Tails), именно в этом порядке: 12.50 %
# вероятность того, что мы получим (Tails,Tails,Tails), именно в этом порядке: 12.50 %
# вероятность того, что мы получим (Heads,Tails,Tails,Heads), именно в этом порядке: 6.25 %
# вероятность того, что мы получим (Tails,Heads,Tails,Heads,Heads), именно в этом порядке: 3.12 %
# ```

# %% [markdown]
# 3. Бросая игральную кость со сторонами ```{1,2,3,3,4,6}```, ответьте на вопросы приведенные ниже:
#
#     * Какова вероятность того, что мы получим ```(3,3,3)```, именно в этом порядке? Присвойте результат переменной ```p_12```.
#
#     * Какова вероятность того, что мы получим ```(3,3,2)```, именно в этом порядке? Присвойте результат переменной ```p_32```.
#
#     * Какова вероятность того, что мы получим ```(3,3,3)```, именно в этом порядке? Присвойте результат переменной ```p_333```.
#
#     * Какова вероятность того, что мы получим ```(3,3,2)```, именно в этом порядке? Присвойте результат переменной ```p_332```.
#
#     * Какова вероятность того, что мы получим ```(1,2,3,4)```, именно в этом порядке? Присвойте результат переменной ```p_1234```.
#
#     * Какова вероятность того, что мы получим ```(3,2,3,2,1)```, именно в этом порядке? Присвойте результат переменной ```p_32321```.
#
#     * Какова вероятность того, что мы получим ```(1,1,1,1,1,5)```, именно в этом порядке? Присвойте результат переменной ```p_111115```.

# %%
#Начало вашего кода
p_12 = (1/6) * (1/6) # результаты не зависят друг от друга, поэтому можем перемножить их вероятности
p_32 = (2/6) * (1/6)
p_333 = 2/6 * 2/6 * 2/6
p_332 = 2/6 * 2/6 * 1/6
p_1234 = (1/6)**3 * 2/6
p_32321 = (2/6)**2 * (1/6)**3
p_111115 = (1/6)**6
#Конец вашего кода
print(f'вероятность того, что мы получим (1,2), именно в этом порядке: {p_12*100:.2f} %')
print(f'вероятность того, что мы получим (3,2), именно в этом порядке: {p_32*100:.2f} %')
print(f'вероятность того, что мы получим (3,3,3), именно в этом порядке: {p_333*100:.2f} %')
print(f'вероятность того, что мы получим (3,3,2), именно в этом порядке: {p_332*100:.2f} %')
print(f'вероятность того, что мы получим (1,2,3,4), именно в этом порядке: {p_1234*100:.2f} %')
print(f'вероятность того, что мы получим (3,2,3,2,1), именно в этом порядке: {p_32321*100:.2f} %')
print(f'вероятность того, что мы получим (1,1,1,1,1,5), именно в этом порядке: {p_111115*100:.2f} %')
# Out:
# вероятность того, что мы получим (1,2), именно в этом порядке: 2.78 %
# вероятность того, что мы получим (3,2), именно в этом порядке: 5.56 %
# вероятность того, что мы получим (3,3,3), именно в этом порядке: 3.70 %
# вероятность того, что мы получим (3,3,2), именно в этом порядке: 1.85 %
# вероятность того, что мы получим (1,2,3,4), именно в этом порядке: 0.15 %
# вероятность того, что мы получим (3,2,3,2,1), именно в этом порядке: 0.05 %
# вероятность того, что мы получим (1,1,1,1,1,5), именно в этом порядке: 0.00 %

# %% [markdown]
# ### Ожидаемые результаты:
#
# ```
# вероятность того, что мы получим (1,2), именно в этом порядке: 2.78 %
# вероятность того, что мы получим (3,2), именно в этом порядке: 5.56 %
# вероятность того, что мы получим (3,3,3), именно в этом порядке: 3.70 %
# вероятность того, что мы получим (3,3,2), именно в этом порядке: 1.85 %
# вероятность того, что мы получим (1,2,3,4), именно в этом порядке: 0.15 %
# вероятность того, что мы получим (3,2,3,2,1), именно в этом порядке: 0.05 %
# вероятность того, что мы получим (1,1,1,1,1,5), именно в этом порядке: 0.00 %
# ```

# %% [markdown]
# 4. Ответьте на вопросы приведенные ниже:
#
#     * У вас 52-карточная колода, какова вероятность вытянуть любые 3 карты масти червей (по очереди)? Присвойте результат переменной ```p_3_hearts```.
#
#     * У вас 52-карточная колода, какова вероятность вытянуть 2 короля любой масти (по очереди)? Присвойте результат переменной ```p_2_kings```.
#
#     * У вас 52-карточная колода, какова вероятность вытянуть 3 вальта любой масти (по очереди)? Присвойте результат переменной ```p_3_jacks```.
#
#     * У вас 52-карточная колода, какова вероятность вытянуть 5 карт (по очереди) любой масти достоинством более 2 и менее 10? Присвойте результат переменной ```p_5_more_2_less_10```.
#
#     * У вас 52-карточная колода, какова вероятность вытянуть 6 карт (по очереди) без единного туза? Присвойте результат переменной ```p_no_ace```.
#
# ![image.png](attachment:image.png)

# %%
#Начало вашего кода
p_3_hearts = 13/52 * 12/51 * 11/50
p_2_kings = 4/52 * 3/51
p_2_jacks = 4/52 * 3/51 * 2/50
p_5_more_2_less_10 = 28/52 * 27/51 * 26/50 * 25/49 * 24/48
p_no_ace = 48/52 * 47/51 * 46/50 * 45/49 * 44/48 * 43/47
#Конец вашего кода
print(f'вероятность вытянуть любые 3 карты масти червей: {p_3_hearts*100:.2f} %')
print(f'вероятность вытянуть 2 короля любой масти: {p_2_kings*100:.2f} %')
print(f'вероятность вытянуть 3 вальта любой масти: {p_2_jacks*100:.2f} %')
print(f'вероятность вытянуть 5 карт (по очереди) любой масти достоинством более 2 и менее 10: {p_5_more_2_less_10*100:.2f} %')
print(f'вероятность вытянуть 6 карт (по очереди) без единного туза: {p_no_ace*100:.2f} %')
# Out:
# вероятность вытянуть любые 3 карты масти червей: 1.29 %
# вероятность вытянуть 2 короля любой масти: 0.45 %
# вероятность вытянуть 3 вальта любой масти: 0.02 %
# вероятность вытянуть 5 карт (по очереди) любой масти достоинством более 2 и менее 10: 3.78 %
# вероятность вытянуть 6 карт (по очереди) без единного туза: 60.28 %

# %% [markdown]
# ### Ожидаемые результаты:
#
# ```
# вероятность вытянуть любые 3 карты масти червей: 1.29 %
# вероятность вытянуть 2 короля любой масти: 0.44 %
# вероятность вытянуть 3 вальта любой масти: 0.02 %
# вероятность вытянуть 5 карт (по очереди) любой масти достоинством более 2 и менее 10: 3.78 %
# вероятность вытянуть 6 карт (по очереди) без единного туза: 60.28 %
# ```

# %% [markdown]
# 5. Ответьте на вопросы приведенные ниже:
#
#     * Какова вероятность получения хотя бы одной пары ```{6,6}``` за 10 бросков двух игральных костей (обе игральные кости выбрасываются одновременно)? Присвойте результат переменной ```p_66_10```.
#
#     * Какова вероятность получения хотя бы одной пары ```{2,3}``` за 20 бросков двух игральных костей (обе игральные кости выбрасываются одновременно)? Присвойте результат переменной ```p_23_20```.
#
#     * Какова вероятность получения хотя бы одной пары чисел чья сумма равна 10 за 15 бросков двух игральных костей (обе игральные кости выбрасываются одновременно)? Присвойте результат переменной ```p_sum_10_15```.
#
#     * Какова вероятность получения хотя бы одной пары чисел чье произведение четное за 5 бросков двух игральных костей (обе игральные кости выбрасываются одновременно)? Присвойте результат переменной ```p_prod_even_5```.
#
# **Внимание:** вам может понадобиться построить пространство элементарных исходов

# %%
#Начало вашего кода
p_66_10 = 1 - (35/36)**10 # взял значения с прошлого д.з
p_23_20 = 1 - (34/36)**20
p_sum_10_15 = 1 - (33/36)**15
p_prod_even_5 = 1 - (0.25)**5 
#Конец вашего кода
print(f'вероятность получения хотя бы одной пары (6, 6) за 10 бросков двух игральных костей: {p_66_10*100:.2f} %')
print(f'вероятность получения хотя бы одной пары (2, 3) за 20 бросков двух игральных костей: {p_23_20*100:.2f} %')
print(f'вероятность получения хотя бы одной пары чисел чья сумма равна 10 за 15 бросков двух игральных костей: {p_sum_10_15*100:.2f} %')
print(f'вероятность получения хотя бы одной пары чисел чье произведение четное за 5 бросков двух игральных костей: {p_prod_even_5*100:.2f} %')
# Out:
# вероятность получения хотя бы одной пары (6, 6) за 10 бросков двух игральных костей: 24.55 %
# вероятность получения хотя бы одной пары (2, 3) за 20 бросков двух игральных костей: 68.12 %
# вероятность получения хотя бы одной пары чисел чья сумма равна 10 за 15 бросков двух игральных костей: 72.89 %
# вероятность получения хотя бы одной пары чисел чье произведение четное за 5 бросков двух игральных костей: 99.90 %

# %% [markdown]
# ### Ожидаемые результаты:
#
# ```
# вероятность получения хотя бы одной пары (6, 6) за 10 бросков двух игральных костей: 24.55 %
# вероятность получения хотя бы одной пары (2, 3) за 20 бросков двух игральных костей: 68.12 %
# вероятность получения хотя бы одной пары чисел чья сумма равна 10 за 15 бросков двух игральных костей: 72.89 %
# вероятность получения хотя бы одной пары чисел чье произведение четное за 5 бросков двух игральных костей: 99.90 %
# ```

# %% [markdown]
# ### Отличная работа
